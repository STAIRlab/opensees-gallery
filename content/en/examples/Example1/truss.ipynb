# %%
import xara 
from xara.load import NodalLoads

#
# Define Model
#

# Create a Model (with two-dimensions and 2 DOF/node)
model = xara.Model(ndm=2, ndf=2)

# Create nodes
model.node(1, (  0.0,  0.0))
model.node(2, (144.0,  0.0))
model.node(3, (168.0,  0.0))
model.node(4, ( 72.0, 96.0))

# Set the boundary conditions
model.fix(1, (1, 1))
model.fix(2, (1, 1))
model.fix(3, (1, 1))

# Define materials for truss elements
# -----------------------------------
model.material("Elastic", 1, E=3000.0, nu=0.3)
model.section("Truss", 1, A=10.0, material=1)
model.section("Truss", 2, A=5.0,  material=1)

# Define elements
# ---------------
# Create truss elements
model.element("Truss", 1, (1, 4), section=1)
model.element("Truss", 2, (2, 4), section=2)
model.element("Truss", 3, (3, 4), section=2)

# Define loads
# ------------
# Define the load at node 4 with components 100 and -50 in x and y:
loads = NodalLoads({4: [100, -50.0]})

# Assign the load to a "Plain" load pattern and scale its load factor linearly in time.


#
# Define Analysis
#
analysis = xara.StaticAnalysis(model, loads)


#
# Perform the analysis
#
analysis.analyze(model)

#
# Print results
#

# print the current state at node 4 and at all elements
u4 = model.nodeDisp(4)
print(f"u4 = {u4}")
# Out:
# ---------------------------------------------------------------------------
# InterpreterError                          Traceback (most recent call last)
# Cell In[1], line 25
#      22 # Define materials for truss elements
#      23 # -----------------------------------
#      24 model.material("Elastic", 1, E=3000.0, nu=0.3)
# ---> 25 model.section("Truss", 1, i=10.0, material=1)
#      26 model.section("Truss", 2, A=5.0,  material=1)
#      28 # Define elements
#      29 # ---------------
#      30 # Create truss elements
#
# File ~/packages/OpenSeesRT/SRC/opensees/openseespy.py:444, in OpenSeesPy.section(self, type, sec_tag, *args, **kwds)
#     441 else:
#     442     shape = None
# --> 444 ret = self._invoke_proc("section", type, sec_tag, *args, **kwds)
#     446 if shape is not None:
#     447     for fiber in shape.fibers:
#
# File ~/packages/OpenSeesRT/SRC/opensees/openseespy.py:226, in OpenSeesPy._invoke_proc(self, proc_name, _final, _return_string, *args, **kwds)
#     222 cmd += comment
#     224 #
#     225 #
# --> 226 ret = self.eval(cmd)
#     227 #
#     228 #
#     230 if ret is None or ret == "":
#
# File ~/packages/OpenSeesRT/SRC/opensees/openseespy.py:262, in OpenSeesPy.eval(self, cmd)
#     260 if self._echo is not None:
#     261     print(cmd, file=self._echo)
# --> 262 return self._interp.eval(cmd)
#
# File ~/packages/OpenSeesRT/SRC/opensees/tcl.py:202, in Interpreter.eval(self, string)
#     199     except:
#     200         pass
# --> 202 raise InterpreterError(err) from None
#
# InterpreterError: Unknown option -i
